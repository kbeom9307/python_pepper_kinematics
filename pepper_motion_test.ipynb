# %%
"""
Move work_pose first, then move 5 centimeters toward left (y axis positive side).
"""

import time
import numpy as np
import naoqi as n
import sys 
import pepper_kinematics as pk
import tkinter as tk

nao_ip = "192.168.0.38"
port = 9559

m = n.ALProxy("ALMotion", nao_ip, port)
m.setAngles(pk.left_arm_tags, pk.left_arm_work_pose, 0.05) # friction speed

time.sleep(1.0)

current_angles = []
for i in range(len(pk.left_arm_tags)): # ALMotion.getanlges arg - str 로 변환
    current_angles.append(m.getAngles(pk.left_arm_tags[i],0))
    
current_angles = [i[0] for i in current_angles] # list 벗겨내고
current_position, current_orientation = pk.left_arm_get_position(current_angles)

target_position = current_position
target_orientation = current_orientation # This is not supported yet

root = tk.Tk()

def left(event):
    print("move left : 1cm")
    target_position[1] = target_position[1] + 0.01 # 1 cm move left
    global target_angles
    target_angles = pk.left_arm_set_position(current_angles, target_position, target_orientation)
    m.setAngles(pk.left_arm_tags, list(target_angles), 0.05)
    
def right(event):
    print("move right : 1cm")
    target_position[1] = target_position[1] - 0.01 # 1 cm move right
    global target_angles 
    target_angles = pk.left_arm_set_position(current_angles, target_position, target_orientation)
    m.setAngles(pk.left_arm_tags, list(target_angles), 0.05)
    
def foward(event):
    print("move foward : 1cm")
    target_position[0] = target_position[0] + 0.01 # 1 cm move foward
    global target_angles
    target_angles = pk.left_arm_set_position(current_angles, target_position, target_orientation)
    m.setAngles(pk.left_arm_tags, list(target_angles), 0.05)
    
def backward(event):
    print("move backward : 1cm")
    target_position[0] = target_position[0] - 0.01 # 1 cm move backward
    global target_angles
    target_angles = pk.left_arm_set_position(current_angles, target_position, target_orientation)
    m.setAngles(pk.left_arm_tags, list(target_angles), 0.05)
    
def up(event):
    print("move up : 1cm")
    target_position[2] = target_position[2] + 0.01 # 1 cm move up
    global target_angles
    target_angles = pk.left_arm_set_position(current_angles, target_position, target_orientation)
    m.setAngles(pk.left_arm_tags, list(target_angles), 0.05)
    
def down(event):
    print("move down : 1cm")
    target_position[2] = target_position[2] - 0.01 # 1 cm move down
    global target_angles
    target_angles = pk.left_arm_set_position(current_angles, target_position, target_orientation)
    m.setAngles(pk.left_arm_tags, list(target_angles), 0.05)
    

def quit(event):
    print("총 이동 거리는 : ? , 좌표는 : ? ")
    global root
    root.destroy()
    

frame = tk.Frame(root, width=100, height=100)
frame.focus_set() # 키보드에 focus
frame.bind("<Left>", left)
frame.bind("<Right>", right)
frame.bind("<Up>", foward)
frame.bind("<Down>", backward)
frame.bind("<Shift-Up>", up)
frame.bind("<Shift-Down>", down)
frame.bind("<Escape>", quit)
frame.pack()

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-7c07bc4aefc1> in <module>()
#      13 port = 9559
#      14
# ---> 15 m = n.ALProxy("ALMotion", nao_ip, port)
#      16 m.setAngles(pk.left_arm_tags, pk.left_arm_work_pose, 0.05) # friction speed
#      17
#
# /home/mmmil-hw/Naoqi/pynaoqi-python2.7-2.5.5.5-linux64/lib/python2.7/site-packages/naoqi.pyc in __init__(self, *args)
#     235             inaoqi.proxy.__init__(self, args[0],  args[1])
#     236         else:
# --> 237             inaoqi.proxy.__init__(self, args[0], args[1], args[2])
#     238
#     239     def call(self, *args):
#
# /home/mmmil-hw/Naoqi/pynaoqi-python2.7-2.5.5.5-linux64/lib/python2.7/site-packages/inaoqi.pyc in __init__(self, *args)
#     271     __repr__ = _swig_repr
#     272     def __init__(self, *args):
# --> 273         this = _inaoqi.new_proxy(*args)
#     274         try: self.this.append(this)
#     275         except: self.this = this
#
# RuntimeError: 	ALBroker::createBroker
# 	Cannot connect to tcp://192.168.0.38:9559

# %%
"""
Move work_pose first, then move 5 centimeters toward left (y axis positive side).
"""

import time
import numpy as np
import naoqi as n
import sys 
import pepper_kinematics as pk
import tkinter as tk

root = tk.Tk()

def left(event):
    print("move left : 1cm")
    target_position[1] = target_position[1] + 0.01 # 1 cm move left
    global target_angles
    target_angles = pk.left_arm_set_position(current_angles, target_position, target_orientation)
    m.setAngles(pk.left_arm_tags, list(target_angles), 0.05)
    
def right(event):
    print("move right : 1cm")
    target_position[1] = target_position[1] - 0.01 # 1 cm move right
    global target_angles 
    target_angles = pk.left_arm_set_position(current_angles, target_position, target_orientation)
    m.setAngles(pk.left_arm_tags, list(target_angles), 0.05)
    
def foward(event):
    print("move foward : 1cm")
    target_position[0] = target_position[0] + 0.01 # 1 cm move foward
    global target_angles
    target_angles = pk.left_arm_set_position(current_angles, target_position, target_orientation)
    m.setAngles(pk.left_arm_tags, list(target_angles), 0.05)
    
def backward(event):
    print("move backward : 1cm")
    target_position[0] = target_position[0] - 0.01 # 1 cm move backward
    global target_angles
    target_angles = pk.left_arm_set_position(current_angles, target_position, target_orientation)
    m.setAngles(pk.left_arm_tags, list(target_angles), 0.05)
    
def up(event):
    print("move up : 1cm")
    target_position[2] = target_position[2] + 0.01 # 1 cm move up
    global target_angles
    target_angles = pk.left_arm_set_position(current_angles, target_position, target_orientation)
    m.setAngles(pk.left_arm_tags, list(target_angles), 0.05)
    
def down(event):
    print("move down : 1cm")
    target_position[2] = target_position[2] - 0.01 # 1 cm move down
    global target_angles
    target_angles = pk.left_arm_set_position(current_angles, target_position, target_orientation)
    m.setAngles(pk.left_arm_tags, list(target_angles), 0.05)
    

def quit(event):
    print("총 이동 거리는 : ? , 좌표는 : ? ")
    global root
    root.destroy()
    
def callback():
    frame.focus_set() # 키보드에 focus
    frame.bind("<Left>", left)
    frame.bind("<Right>", right)
    frame.bind("<Up>", foward)
    frame.bind("<Down>", backward)
    frame.bind("<Shift-Up>", up)
    frame.bind("<Shift-Down>", down)
    frame.bind("<Escape>", quit)
    frame.pack()
    
def callback2():
    lbl = tk.Label(root, text = "coordinate")
    lbl.pack()
    
    txt = tk.Entry(root)
    txt.pack()
    
frame = tk.Frame(root, width=300, height=300)

btn=tk.Button(root, text="control", command = callback)
btn.pack()

btn2=tk.Button(root, text="place", command = callback2)
btn2.pack()

root.mainloop()

# %%
import tkinter as tk

root = tk.Tk()
frame = tk.Frame(root, width=300, height=300)
btn=tk.Button(root, text="control")
btn.pack()
root.mainloop()
# Out:
# <bound method Button.grab_status of <Tkinter.Button instance at 0x7f28170be758>>
